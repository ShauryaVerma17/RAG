# %%
import trafilatura as tf

# %%
downloaded = tf.fetch_url("https://en.wikipedia.org/wiki/World_Health_Organization")

# %%
if downloaded is not None:
    result = tf.extract(downloaded, target_language="en")
    print(result)
# Out:
# World Health Organization
# Abbreviation | WHO |
# ---|---|
# Pronunciation |
# |
# Formation | 7 April 1948 |
# Type | United Nations specialized agency |
# Legal status | Active |
# Headquarters | Geneva, Switzerland 46°13′56″N 06°08′03″E / 46.23222°N 6.13417°E |
# Tedros Adhanom Ghebreyesus | |
# Deputy Director General | Michael Ryan |
# Parent organization | United Nations Economic and Social Council |
# Budget | $6.83 billion (2024–25) |
# Website | who.int |
# The World Health Organization (WHO) is a specialized agency of the United Nations responsible for international public health.[2] It is headquartered in Geneva, Switzerland, and has six regional offices[3] and 150 field offices worldwide.[4]
# ...
